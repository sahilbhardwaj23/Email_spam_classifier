# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_predict, StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import gensim
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize

# %%
df=pd.read_csv('cleaned_text.csv')

# %%
df.sample(10)
# Out:
#       label                                               text  word_count  \
# 13279  spam  husband stayed hotel monaco  day october  cann...          98
# 9840   spam  subject investor communiqup  get abzt first th...        1248
# 851     ham                                    ill text drop x           8
# 8877   spam  subject hard even cuumm not leave hanging toni...          32
# 6828    ham  subject union gas thamm  tom  thamm  well came...         143
# 12336   ham  url url date not supplied mark two many wonder...          73
# 12817  spam  free cd rom lesson url choose number title lea...         215
# 2065    ham                     table occupied im waiting tree           8
# 9638    ham  subject fw piss side road  original message tc...         162
# 13597  spam  making obligatory trip chicago area visit fami...          69
#
#        num_stop_words  num_chars  num_punctuation_chars  \
# 13279              49        512                     10
# 9840              362       6760                    172
# 851                 4         31                      1
# 8877               11        156                      8
# 6828               42        677                     15
# 12336              25        412                      0
# 12817              72       1264                      0
# 2065                3         45                      3
# 9638               19        631                     56
# 13597              30        380                     11
#
#        word_count_after_preprocessing  num_chars_after_preprocessing
# 13279                              48                            318
# 9840                              593                           4636
# 851                                 4                             15
# 8877                               15                            100
# 6828                               65                            438
# 12336                              48                            319
# 12817                             144                            953
# 2065                                5                             30
# 9638                               65                            408
# 13597                              38                            253

# %%
# Preprocessing: Tokenize text and remove unnecessary characters
def preprocess_text(text):
    if isinstance(text, str):  # Ensure text is a string
        # Tokenize the sentence into words
        tokens = word_tokenize(text.lower())  # Lowercase the text
        return tokens
    return []  # Return empty list for None or non-string values

# %%
# Apply the preprocessing function to the text column
df['tokenized_text'] = df['text'].apply(preprocess_text)

# %%
df.sample(5)
# Out:
#       label                                               text  word_count  \
# 12108   ham  url url date not supplied british scientist vo...          25
# 6600   spam  subject snap explosion immoderate massive rock...         191
# 14528   ham  consistently disappointed throughout stay jame...         299
# 1215    ham                                        plan pongal           5
# 6088    ham  subject tenaska iv   please change demand fee ...          50
#
#        num_stop_words  num_chars  num_punctuation_chars  \
# 12108               9        145                      0
# 6600                8       1357                     23
# 14528             152       1607                     49
# 1215                3         26                      1
# 6088               10        221                     10
#
#        word_count_after_preprocessing  num_chars_after_preprocessing  \
# 12108                              17                            110
# 6600                              158                           1267
# 14528                             149                           1025
# 1215                                2                             11
# 6088                               16                            128
#
#                                           tokenized_text
# 12108  [url, url, date, not, supplied, british, scien...
# 6600   [subject, snap, explosion, immoderate, massive...
# 14528  [consistently, disappointed, throughout, stay,...
# 1215                                      [plan, pongal]
# 6088   [subject, tenaska, iv, please, change, demand,...

# %%
sentences=df['tokenized_text'].to_list()

# %%
len(sentences)
# Out:
# 14617

# %%
sentences
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'bugis',
#   'n',
#   'great',
#   'world',
#   'la',
#   'e',
#   'buffet',
#   'cine',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'u', 'oni'],
#  ['free',
#   'entry',
#   'wkly',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receive',
#   'entry',
#   'questionstd',
#   'txt',
#   'ratetcs',
#   'apply',
#   'overs'],
#  ['u', 'dun', 'say', 'early', 'hor', 'u', 'c', 'already', 'say'],
#  ['nah', 'dont', 'think', 'go', 'usf', 'life', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darling',
#   'week',
#   'no',
#   'word',
#   'back',
#   'id',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even',
#   'brother',
#   'not',
#   'like',
#   'speak',
#   'me',
#   'treat',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertune',
#   'callers',
#   'press',
#   'copy',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'selected',
#   'receivea',
#   'prize',
#   'reward',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['mobile',
#   'month',
#   'more',
#   'u',
#   'r',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'mobile',
#   'camera',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['im',
#   'gon',
#   'na',
#   'home',
#   'soon',
#   'dont',
#   'want',
#   'talk',
#   'stuff',
#   'anymore',
#   'tonight',
#   'k',
#   'ive',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'win',
#   'cash',
#   'pound',
#   'txt',
#   'csh',
#   'send',
#   'cost',
#   'pday',
#   'days',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'week',
#   'free',
#   'membership',
#   'prize',
#   'jackpot',
#   'txt',
#   'word',
#   'claim',
#   'no',
#   'tc',
#   'lccltd',
#   'pobox',
#   'ldnwarw'],
#  ['ive',
#   'searching',
#   'right',
#   'word',
#   'thank',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'help',
#   'granted',
#   'fulfil',
#   'promise',
#   'wonderful',
#   'blessing',
#   'times'],
#  ['date', 'sunday', 'will'],
#  ['xxxmobilemovieclub',
#   'use',
#   'credit',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'message',
#   'click',
#   'xxxmobilemovieclubcomnqjkgighjjgcbl'],
#  ['oh', 'kim', 'watching'],
#  ['eh',
#   'u',
#   'remember',
#   'spell',
#   'name',
#   'yes',
#   'did',
#   'v',
#   'naughty',
#   'make',
#   'v',
#   'wet'],
#  ['fine', 'thats', 'way', 'u', 'feel', 'thats', 'way', 'gota', 'b'],
#  ['england',
#   'v',
#   'macedonia',
#   'dont',
#   'miss',
#   'goalsteam',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'eg',
#   'england',
#   'trywales',
#   'scotland',
#   'txt',
#   'poboxoxwwq'],
#  ['seriously', 'spell', 'name'],
#  ['im', 'going', 'try', 'month', 'ha', 'ha', 'joking'],
#  ['pay', 'first', 'lar', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'u',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff', 'alright', 'no', 'way', 'meet', 'sooner'],
#  ['forced',
#   'eat',
#   'slice',
#   'im',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'sucks',
#   'mark',
#   'getting',
#   'worried',
#   'know',
#   'im',
#   'sick',
#   'turn',
#   'pizza',
#   'lol'],
#  ['lol', 'always', 'convincing'],
#  ['catch',
#   'bus',
#   'frying',
#   'egg',
#   'make',
#   'tea',
#   'eating',
#   'mom',
#   'left',
#   'dinner',
#   'feel',
#   'love'],
#  ['im',
#   'back',
#   'amp',
#   'packing',
#   'car',
#   'now',
#   'ill',
#   'let',
#   'know',
#   'there',
#   'room'],
#  ['ahhh', 'work', 'vaguely', 'remember', 'that', 'feel', 'like', 'lol'],
#  ['wait',
#   'thats',
#   'still',
#   'not',
#   'clear',
#   'not',
#   'sure',
#   'sarcastic',
#   'thats',
#   'x',
#   'doesnt',
#   'want',
#   'live',
#   'u'],
#  ['yeah',
#   'got',
#   'v',
#   'apologetic',
#   'n',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'that',
#   'till',
#   'but',
#   'wont',
#   'go',
#   'there',
#   'not',
#   'badly',
#   'cheers',
#   'you'],
#  ['k', 'tell', 'anything', 'you'],
#  ['fear', 'fainting', 'housework', 'did', 'quick', 'cuppa'],
#  ['thanks',
#   'subscription',
#   'ringtone',
#   'uk',
#   'mobile',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'replying',
#   'yes',
#   'no',
#   'reply',
#   'no',
#   'not',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'timing',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'learn',
#   'nd',
#   'may',
#   'but',
#   'lesson',
#   'am'],
#  ['oops', 'ill', 'let', 'know', 'roommate', 'done'],
#  ['see', 'letter', 'b', 'car'],
#  ['anything', 'lor', 'u', 'decide'],
#  ['hello',
#   'hows',
#   'saturday',
#   'go',
#   'texting',
#   'see',
#   'youd',
#   'decided',
#   'anything',
#   'tomo',
#   'not',
#   'im',
#   'trying',
#   'invite',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'watts',
#   'wanted',
#   'sure',
#   'great',
#   'weekend',
#   'abiola'],
#  ['forget',
#   'tell',
#   'want',
#   'need',
#   'you',
#   'crave',
#   'but',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'tried',
#   'call',
#   'reply',
#   'sm',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'delivery',
#   'tomorrow'],
#  ['seeing'],
#  ['great', 'hope', 'like', 'man', 'well', 'endowed', 'ltgt', 'inches'],
#  ['no', 'callsmessagesmissed', 'call'],
#  ['didnt', 'get', 'hep', 'b', 'immunisation', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'tyler',
#   'cant',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['u',
#   'dont',
#   'know',
#   'stubborn',
#   'am',
#   'didnt',
#   'even',
#   'want',
#   'go',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'im',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'weak',
#   'suckers'],
#  ['thinked', 'me', 'first', 'time', 'saw', 'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'ltgt',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'ltgt'],
#  ['k',
#   'fyi',
#   'x',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'embarassed',
#   'accomodations',
#   'thought',
#   'liked',
#   'it',
#   'since',
#   'best',
#   'could',
#   'always',
#   'seemed',
#   'happy',
#   'cave',
#   'im',
#   'sorry',
#   'didnt',
#   'dont',
#   'give',
#   'im',
#   'sorry',
#   'offered',
#   'im',
#   'sorry',
#   'room',
#   'embarassing'],
#  ['sms',
#   'ac',
#   'sptv',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lturlgt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'yours',
#   'call',
#   'now',
#   'c',
#   'suprman',
#   'v',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bxipwe',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'ill', 'call', 'later', 'meeting'],
#  ['tell', 'reached'],
#  ['yesgauti', 'sehwag', 'odi', 'series'],
#  ['gon',
#   'na',
#   'pick',
#   'burger',
#   'way',
#   'home',
#   'cant',
#   'even',
#   'move',
#   'pain',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situation', 'seekers'],
#  ['part', 'checking', 'iq'],
#  ['sorry', 'roommate', 'took', 'forever', 'ok', 'come', 'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'said',
#   'wun',
#   'cut',
#   'v',
#   'short',
#   'said',
#   'cut',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'pleased',
#   'advise',
#   'following',
#   'recent',
#   'review',
#   'mob',
#   'no',
#   'awarded',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'song',
#   'dedicated',
#   'day',
#   'song',
#   'u',
#   'dedicate',
#   'me',
#   'send',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'eurodisinc',
#   'trav',
#   'acoentry',
#   'claim',
#   'txt',
#   'dis',
#   'morefrmmob',
#   'shracomorsglsuplt',
#   'ls',
#   'aj'],
#  ['hear', 'new', 'divorce', 'barbie', 'come', 'ken', 'stuff'],
#  ['plane', 'give', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'save', 'money', 'hee'],
#  ['finished', 'class', 'you'],
#  ['hi', 'babe', 'im', 'home', 'wan', 'na', 'something', 'xx'],
#  ['kkwhere', 'youhow', 'performed'],
#  ['u', 'call', 'now'],
#  ['waiting', 'machan', 'call', 'free'],
#  ['thats', 'cool', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['like', 'people', 'much', 'but', 'shy', 'pa'],
#  ['not', 'operate', 'ltgt'],
#  ['not', 'here', 'still', 'looking', 'job', 'much', 'ta', 'earn', 'there'],
#  ['sorry', 'ill', 'call', 'later'],
#  ['k', 'call', 'ah'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'later', 'dont', 'network', 'urgnt', 'sm', 'me'],
#  ['real',
#   'u',
#   'getting',
#   'yo',
#   'need',
#   'ticket',
#   'one',
#   'jacket',
#   'im',
#   'done',
#   'already',
#   'used',
#   'multis'],
#  ['yes',
#   'started',
#   'send',
#   'request',
#   'make',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'im',
#   'back',
#   'bed',
#   'double',
#   'coin',
#   'factory',
#   'too',
#   'got',
#   'ta',
#   'cash',
#   'nitros'],
#  ['im', 'really', 'not', 'still', 'tonight', 'babe'],
#  ['ela', 'kanoil', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'dont',
#   'stand',
#   'close',
#   'tho',
#   'youll',
#   'catch',
#   'something'],
#  ['sorry',
#   'pain',
#   'ok',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'casualty',
#   'mean',
#   'havent',
#   'done',
#   'stuffmoro',
#   'includes',
#   'time',
#   'sheet',
#   'that',
#   'sorry'],
#  ['smile',
#   'pleasure',
#   'smile',
#   'pain',
#   'smile',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'sum',
#   'hurt',
#   'u',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'see',
#   'u',
#   'smiling'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'ampm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['havent',
#   'planning',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'got',
#   'show',
#   'e',
#   'afternoon',
#   'u',
#   'finish',
#   'work',
#   'already'],
#  ['free',
#   'ringtone',
#   'waiting',
#   'collected',
#   'simply',
#   'text',
#   'password',
#   'mix',
#   'verify',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'h',
#   'ppw'],
#  ['watching', 'telugu', 'moviewat', 'abt', 'u'],
#  ['see', 'finish', 'load', 'loan', 'pay'],
#  ['hi',
#   'wk',
#   'ok',
#   'hols',
#   'now',
#   'yes',
#   'bit',
#   'run',
#   'forgot',
#   'hairdresser',
#   'appointment',
#   'four',
#   'need',
#   'get',
#   'home',
#   'n',
#   'shower',
#   'beforehand',
#   'cause',
#   'prob',
#   'u'],
#  ['see', 'cup', 'coffee', 'animation'],
#  ['please', 'dont', 'text', 'anymore', 'nothing', 'else', 'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'legal',
#   'wen',
#   'pick',
#   'up',
#   'u',
#   'ave',
#   'x',
#   'am',
#   'xx'],
#  ['im',
#   'still',
#   'looking',
#   'car',
#   'buy',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['wow',
#   'youre',
#   'right',
#   'didnt',
#   'mean',
#   'that',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'changed',
#   'search',
#   'location',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'wish',
#   'birthday',
#   'thanks',
#   'making',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'ill', 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'considering',
#   'computer',
#   'isnt',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'mom',
#   'like',
#   'better',
#   'not',
#   'lying',
#   'always',
#   'one',
#   'play',
#   'jokes'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['plural', 'noun', 'research'],
#  ['going', 'dinnermsg', 'after'],
#  ['im',
#   'ok',
#   'wif',
#   'co',
#   'like',
#   'try',
#   'new',
#   'things',
#   'but',
#   'scared',
#   'u',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'u',
#   'said',
#   'not',
#   'loud'],
#  ['gent',
#   'trying',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'k',
#   'valid',
#   'hrs',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'formal',
#   'anyway',
#   'im',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'im',
#   'eatin',
#   'much',
#   'n',
#   'puttin',
#   'weighthaha',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'cabin',
#   'pa',
#   'said',
#   'happy',
#   'bday',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invited',
#   'apartment',
#   'went',
#   'there'],
#  ['winner',
#   'u',
#   'specially',
#   'selected',
#   'receive',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim',
#   'pmin'],
#  ['goodo',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   'eggpotato',
#   'ratio',
#   'tortilla',
#   'needed'],
#  ['hmmmy',
#   'uncle',
#   'informed',
#   'he',
#   'paying',
#   'school',
#   'directly',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'account',
#   'statement',
#   'show',
#   'unredeemed',
#   'bonus',
#   'points',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'mobile',
#   'no',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'final',
#   'try',
#   'contact',
#   'u',
#   'call',
#   'landline',
#   'boxwrc',
#   'ppm'],
#  ['new', 'address', 'applespairsall', 'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'selected',
#   'receive',
#   'award',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['going', 'sao', 'mu', 'today', 'done'],
#  ['predict', 'wat', 'time', 'finish', 'buying'],
#  ['good', 'stuff', 'do'],
#  ['knowyetunde',
#   'hasnt',
#   'sent',
#   'money',
#   'yet',
#   'sent',
#   'text',
#   'not',
#   'bother',
#   'sending',
#   'over',
#   'dont',
#   'involve',
#   'anything',
#   'shouldnt',
#   'imposed',
#   'anything',
#   'first',
#   'place',
#   'that',
#   'apologise'],
#  ['room'],
#  ['hey',
#   'girl',
#   'r',
#   'u',
#   'hope',
#   'u',
#   'r',
#   'well',
#   'del',
#   'r',
#   'bak',
#   'long',
#   'time',
#   'no',
#   'c',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['kkhow', 'much', 'cost'],
#  ['im', 'home'],
#  ['dear', 'call', 'tmorrowpls', 'accomodate'],
#  ['first', 'answer', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'q',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'u',
#   'know',
#   'country',
#   'algarve',
#   'in',
#   'txt',
#   'ansr',
#   'sptyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'nt',
#   'eca',
#   'pmsgp'],
#  ['haf', 'msn', 'yijuehotmailcom'],
#  ['there', 'call', 'meet'],
#  ['no', 'no', 'check', 'room', 'befor', 'activity'],
#  ['youll',
#   'not',
#   'rcv',
#   'msg',
#   'chat',
#   'svc',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'u',
#   'get',
#   'nothing',
#   'u',
#   'must',
#   'age',
#   'verify',
#   'yr',
#   'network',
#   'try'],
#  ['got',
#   'c',
#   'lazy',
#   'type',
#   'forgot',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'v',
#   'nice'],
#  ['k', 'text', 'youre', 'way'],
#  ['sir', 'waiting', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'little',
#   'thing',
#   'lovable',
#   'persons',
#   'cozsomtimes',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'hearts',
#   'gud',
#   'ni'],
#  ['know', 'are', 'pls', 'open', 'back'],
#  ['yes', 'see', 'ya', 'not', 'dot'],
#  ['whats', 'staff', 'name', 'taking', 'class', 'us'],
#  ['freemsg',
#   'havent',
#   'replied',
#   'text',
#   'im',
#   'randy',
#   'sexy',
#   'female',
#   'live',
#   'local',
#   'luv',
#   'hear',
#   'u',
#   'netcollex',
#   'ltd',
#   'p',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'end'],
#  ['ummmawill',
#   'call',
#   'check',
#   'inour',
#   'life',
#   'begin',
#   'qatar',
#   'pls',
#   'pray',
#   'hard'],
#  ['ki', 'deleted', 'contact', 'why'],
#  ['sindu', 'got', 'job', 'birla', 'soft'],
#  ['wine', 'flowing', 'im', 'nevering'],
#  ['yup', 'thk', 'cine', 'better', 'co', 'no', 'need', 'go', 'plaza', 'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['everywhere',
#   'dirt',
#   'floor',
#   'windows',
#   'even',
#   'shirt',
#   'sometimes',
#   'open',
#   'mouth',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'world',
#   'without',
#   'you',
#   'half',
#   'chore',
#   'too',
#   'time',
#   'joy',
#   'me',
#   'lot',
#   'tv',
#   'show',
#   'ill',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'mist',
#   'time',
#   'done',
#   'become',
#   'one'],
#  ['aaooooright', 'work'],
#  ['im', 'leaving', 'house', 'now'],
#  ['hello',
#   'love',
#   'doing',
#   'get',
#   'interview',
#   'today',
#   'happy',
#   'good',
#   'boy',
#   'think',
#   'meare',
#   'missing'],
#  ['customer',
#   'service',
#   'annoncement',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'you',
#   'please',
#   'call',
#   'arrange',
#   'delivery'],
#  ['winner',
#   'u',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'already',
#   'envy',
#   'everyone',
#   'see',
#   'real',
#   'life'],
#  ['new', 'car', 'house', 'parentsi', 'new', 'job', 'hand'],
#  ['im',
#   'love',
#   'you',
#   'im',
#   'excited',
#   'day',
#   'spend',
#   'you',
#   'make',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'f',
#   'inviting',
#   'friend',
#   'reply',
#   'yes',
#   'no',
#   'see',
#   'stop',
#   'send',
#   'stop',
#   'frnd'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'way',
#   'u',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'u',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'ur',
#   'mobile',
#   'internetservice',
#   'menu'],
#  ['place', 'ur', 'point', 'e', 'culture', 'module', 'already'],
#  ['urgent',
#   'trying',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   's',
#   'valid',
#   'hrs'],
#  ['hi',
#   'frnd',
#   'best',
#   'way',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'beloved',
#   'ones'],
#  ['great', 'escape', 'fancy', 'bridge', 'but', 'need', 'lager', 'see', 'tomo'],
#  ['yes', 'completely', 'formclark', 'also', 'utter', 'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard',
#   'ya',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'u',
#   'discus',
#   'liao'],
#  ['time', 'coming', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'forgot',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'u',
#   'clue',
#   'spanish',
#   'begin',
#   'm'],
#  ['well', 'im', 'gon', 'na', 'finish', 'bath', 'now', 'goodfine', 'night'],
#  ['let', 'know', 'youve', 'got', 'money', 'carlos', 'make', 'call'],
#  ['u', 'still', 'going', 'mall'],
#  ['turn',
#   'friend',
#   'staying',
#   'whole',
#   'show',
#   'wont',
#   'back',
#   'til',
#   'ltgt',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   'ltgt',
#   'worth'],
#  ['text', 'her', 'doesnt', 'reply', 'let', 'know', 'log'],
#  ['hi',
#   'spoke',
#   'maneesha',
#   'v',
#   'wed',
#   'like',
#   'know',
#   'satisfied',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'yes',
#   'no'],
#  ['lifted',
#   'hope',
#   'offer',
#   'money',
#   'need',
#   'especially',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studying',
#   'anyways',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'u', 'trust', 'me'],
#  ['ok', 'gentleman', 'treat', 'dignity', 'respect'],
#  ['will', 'guy', 'close'],
#  ['going', 'nothing', 'greatbye'],
#  ['hello',
#   'handsome',
#   'finding',
#   'job',
#   'not',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'net',
#   'mummy',
#   'wheres',
#   'boytoy',
#   'miss'],
#  ['haha', 'awesome', 'minute'],
#  ['please',
#   'call',
#   'customer',
#   'service',
#   'representative',
#   'freephone',
#   'ampm',
#   'guaranteed',
#   'cash',
#   'prize'],
#  ['got', 'xmas', 'radio', 'times', 'not', 'get'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'u',
#   'finish',
#   'k'],
#  ['unique', 'enough', 'find', 'th', 'august'],
#  ['im',
#   'sorry',
#   'ive',
#   'joined',
#   'league',
#   'people',
#   'dont',
#   'keep',
#   'touch',
#   'mean',
#   'great',
#   'deal',
#   'me',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'personal',
#   'cost',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'course'],
#  ['stop',
#   'itself',
#   'however',
#   'suggest',
#   'stay',
#   'someone',
#   'able',
#   'give',
#   'or',
#   'every',
#   'stool'],
#  ['doing',
#   'hope',
#   'youve',
#   'settled',
#   'new',
#   'school',
#   'year',
#   'wishin',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['u', 'got', 'person', 'story'],
#  ['hamster', 'dead', 'hey', 'tmr', 'meet', 'pm', 'orchard', 'mrt'],
#  ['hi',
#   'kate',
#   'evening',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'but',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'u',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'ltgt', 'at'],
#  ['sent', 'ltgt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'txt',
#   'u',
#   'finish',
#   'u',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refilled',
#   'successfully',
#   'inr',
#   'ltdecimalgt',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'r',
#   'ltdecimalgt',
#   'transaction',
#   'id',
#   'kr',
#   'ltgt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['u', 'call', 'alter', 'ok'],
#  ['say',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'can',
#   'not',
#   'oredi',
#   'lar'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['please',
#   'give',
#   'u',
#   'connection',
#   'today',
#   'ltdecimalgt',
#   'refund',
#   'bill'],
#  ['shoot', 'big', 'load', 'get', 'ready'],
#  ['whats', 'bruv', 'hope', 'great', 'break', 'rewarding', 'semester'],
#  ['home', 'always', 'chat'],
#  ['kkgoodstudy', 'well'],
#  ['yup', 'noe', 'leh'],
#  ['sound', 'great', 'home', 'now'],
#  ['finally', 'match', 'heading', 'towards', 'draw', 'prediction'],
#  ['tired', 'havent', 'slept', 'well', 'past', 'nights'],
#  ['easy', 'ahsen', 'got', 'selected', 'mean', 'good'],
#  ['take', 'exam', 'march'],
#  ['yeah',
#   'should',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'there',
#   'anyway',
#   'help',
#   'let',
#   'know',
#   'but',
#   'sure',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['o',
#   'called',
#   'ubandu',
#   'run',
#   'without',
#   'installing',
#   'hard',
#   'diskyou',
#   'use',
#   'o',
#   'copy',
#   'important',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop'],
#  ['u',
#   'say',
#   'leh',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'v',
#   'romantic',
#   'jus',
#   'bit',
#   'lor',
#   'thk',
#   'e',
#   'nite',
#   'scenery',
#   'not',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'no',
#   'collect',
#   'todayfrom',
#   'optout',
#   'gbpmtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'call',
#   'me',
#   'need',
#   'someone',
#   'talk',
#   'to'],
#  ['u',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'ur',
#   'career',
#   'flyng',
#   'start',
#   'find',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'ur',
#   'star',
#   'sign',
#   'e',
#   'g',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'strict',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'teach',
#   'lessons',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'ltgt',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right'],
#  ['dear', 'going', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'im'],
#  ['yeshere', 'tv', 'always', 'available', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'u',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'u',
#   'join',
#   'p',
#   'reply',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recdthirtyeight',
#   'penny'],
#  ['printed', 'oh', 'ltgt', 'come', 'upstairs'],
#  ['ill', 'little', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['youwhen', 'wil', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'person',
#   'dont',
#   'argue',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'amp',
#   'say',
#   'im',
#   'always',
#   'correct'],
#  ['u',
#   'secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcall'],
#  ['tomarrow', 'final', 'hearing', 'laptop', 'case', 'cant'],
#  ['pleassssssseeeeee', 'tel', 'v', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'shining',
#   'on',
#   'meant',
#   'signing',
#   'but',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'u',
#   'dat',
#   'im',
#   'baig',
#   'face',
#   'watch',
#   'but',
#   'really',
#   'like',
#   'e',
#   'watch',
#   'u',
#   'gave',
#   'co',
#   'fr',
#   'u',
#   'thanx',
#   'everything',
#   'dat',
#   'uve',
#   'done',
#   'today',
#   'im',
#   'touched'],
#  ['u', 'dont', 'remember', 'old', 'commercial'],
#  ['late', 'said', 'website', 'didnt', 'dont', 'slipper'],
#  ['asked', 'call', 'ok'],
#  ['kallis', 'wont', 'bat', 'nd', 'innings'],
#  ['didnt',
#   'work',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'ill',
#   'fix',
#   'ready',
#   'time',
#   'wake',
#   'up',
#   'dearly',
#   'missed',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'cd',
#   'voucher',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'tncs'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'u',
#   'dnt',
#   'take',
#   'seriously',
#   'coz',
#   'angry',
#   'childish',
#   'n',
#   'true',
#   'way',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'n',
#   'luv',
#   'kettoda',
#   'manda',
#   'nice',
#   'day',
#   'da'],
#  ['doinghow', 'you'],
#  ['ups',
#   'days',
#   'also',
#   'shipping',
#   'company',
#   'take',
#   'wks',
#   'way',
#   'usps',
#   'take',
#   'week',
#   'but',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff'],
#  ['im', 'back', 'lem', 'me', 'know', 'youre', 'ready'],
#  ['dont',
#   'necessarily',
#   'expect',
#   'done',
#   'get',
#   'back',
#   'though',
#   'im',
#   'headin'],
#  ['mmm', 'yummy', 'babe', 'nice', 'jolt', 'suzy'],
#  ['lover', 'need'],
#  ['tried',
#   'contact',
#   'reply',
#   'offer',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'mins',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'call'],
#  ['im', 'parked', 'next', 'mini', 'coming', 'today', 'think'],
#  ['yup'],
#  ['anyway',
#   'im',
#   'going',
#   'shopping',
#   'now',
#   'co',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'u',
#   'liao'],
#  ['no', 'luton', 'ring', 'ur', 'around', 'h'],
#  ['hey',
#   'really',
#   'horny',
#   'want',
#   'chat',
#   'see',
#   'naked',
#   'text',
#   'hot',
#   'text',
#   'charged',
#   'pm',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['dint', 'come', 'us'],
#  ['same', 'wana', 'plan', 'trip', 'sometme'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'get', 'hold'],
#  ['ur',
#   'ringtone',
#   'service',
#   'changed',
#   'free',
#   'credits',
#   'go',
#   'clubmobilescom',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'pwk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['evo', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'uk',
#   'single',
#   'chart',
#   'mobile',
#   'week',
#   'choose',
#   'top',
#   'quality',
#   'ringtone',
#   'message',
#   'free',
#   'charge'],
#  ['come', 'mu', 'sorting', 'narcotic', 'situation'],
#  ['night',
#   'ended',
#   'another',
#   'day',
#   'morning',
#   'come',
#   'special',
#   'way',
#   'may',
#   'smile',
#   'like',
#   'sunny',
#   'ray',
#   'leaf',
#   'worry',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'genuine',
#   'hmv',
#   'voucher',
#   'won',
#   'answer',
#   'easy',
#   'questions',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'info'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesome', 'ill', 'see', 'bit'],
#  ['sent', 'it', 'type', 'food', 'like'],
#  ['done', 'handed', 'in', 'celebration', 'full', 'swing', 'yet'],
#  ['got', 'called', 'tool'],
#  ['wen',
#   'u',
#   'miss',
#   'someone',
#   'person',
#   'definitely',
#   'special',
#   'u',
#   'but',
#   'person',
#   'special',
#   'miss',
#   'them',
#   'keepintouch',
#   'gdeve'],
#  ['ok', 'asked', 'money', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'last',
#   'night',
#   'get',
#   'ahold',
#   'anybody',
#   'let',
#   'know',
#   'ill',
#   'throw'],
#  ['k', 'might', 'come', 'tonight', 'class', 'let', 'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'r',
#   'u',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'thats',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenny',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'me',
#   'not',
#   'love',
#   'life',
#   'but',
#   'love',
#   'people',
#   'life',
#   'world',
#   'call',
#   'friends',
#   'call',
#   'world',
#   'ge'],
#  ['dearshall',
#   'mail',
#   'tonitebusy',
#   'streetshall',
#   'update',
#   'tonitethings',
#   'looking',
#   'okvarunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollubut',
#   'good',
#   'one',
#   'real',
#   'sense'],
#  ['hey', 'told', 'name', 'gautham', 'ah'],
#  ['haf', 'u', 'found', 'him', 'feel', 'stupid', 'da', 'v', 'cam', 'working'],
#  ['oops', 'got', 'bit'],
#  ['much', 'buzy'],
#  ['accidentally', 'deleted', 'message', 'resend', 'please'],
#  ['tmobile',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'thfebtcs',
#   'apply'],
#  ['unless', 'situation', 'go', 'gurl', 'would', 'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'cry',
#   'but',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'u',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need', 'coffee', 'run', 'tomocant', 'believe', 'time', 'week', 'already'],
#  ['awesome',
#   'remember',
#   'last',
#   'time',
#   'got',
#   'somebody',
#   'high',
#   'first',
#   'time',
#   'diesel',
#   'v'],
#  ['shit',
#   'really',
#   'shocking',
#   'scary',
#   'cant',
#   'imagine',
#   'second',
#   'def',
#   'night',
#   'out',
#   'u',
#   'think',
#   'somewhere',
#   'could',
#   'crash',
#   'night',
#   'save',
#   'taxi'],
#  ['oh', 'way', 'food', 'fridge', 'want', 'go', 'meal', 'tonight'],
#  ['womdarfull', 'actor'],
#  ['sms',
#   'ac',
#   'blind',
#   'date',
#   'u',
#   'rodds',
#   'm',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'sms',
#   'acwicmbcktzr',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'remb', 'think', 'book'],
#  ['jos', 'ask', 'u', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'friendship',
#   'hanging',
#   'thread',
#   'cause',
#   'u',
#   'wont',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'newest',
#   'selection',
#   'content',
#   'games',
#   'tones',
#   'gossip',
#   'babe',
#   'sport',
#   'keep',
#   'mobile',
#   'fit',
#   'funky',
#   'text',
#   'wap'],
#  ['garage', 'keys', 'arent', 'bookshelf'],
#  ['today',
#   'accept',
#   'dayu',
#   'accept',
#   'as',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'week',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'nowtcs',
#   'winnersclub',
#   'po',
#   'box',
#   'm',
#   'uz',
#   'gbpweek'],
#  ['say',
#   'hell',
#   'give',
#   'call',
#   'friend',
#   'got',
#   'money',
#   'but',
#   'he',
#   'definitely',
#   'buying',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'u',
#   'day',
#   'normal',
#   'waythis',
#   'real',
#   'me',
#   'ur',
#   'uniquei',
#   'hope',
#   'know',
#   'u',
#   'rest',
#   'mylife',
#   'hope',
#   'u',
#   'find',
#   'wot',
#   'lost'],
#  ['made', 'day', 'great', 'day', 'too'],
#  ['kkadvance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'go',
#   'kb',
#   'n',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'no', 'friend', 'im', 'afraid'],
#  ['december',
#   'only',
#   'mobile',
#   'mths',
#   'entitled',
#   'update',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'free',
#   'call',
#   'mobile',
#   'update',
#   'co',
#   'free'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'babe', 'love', 'ya', 'kiss'],
#  ['hey', 'dont', 'go', 'watch', 'x', 'men', 'lunch', 'haha'],
#  ['cud',
#   'u',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'b',
#   'bit',
#   'l',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete',
#   'x'],
#  ['would',
#   'great',
#   'well',
#   'guild',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewhere',
#   'get',
#   'touch',
#   'weekend',
#   'plan',
#   'take',
#   'flight',
#   'good',
#   'week'],
#  ['no', 'problem', 'doing'],
#  ['hi', 'dahow', 'today', 'class'],
#  ['id',
#   'say',
#   'thats',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'know',
#   'track',
#   'record',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'youre', 'parked'],
#  ['im', 'reading', 'text', 'sent', 'you', 'meant', 'joke', 'read', 'light'],
#  ['kkapo', 'kgood', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'tomo',
#   'return',
#   'immediately',
#   'something'],
#  ['call',
#   'germany',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['chance',
#   'might',
#   'evaporated',
#   'soon',
#   'violated',
#   'privacy',
#   'stealing',
#   'phone',
#   'number',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'all',
#   'please',
#   'not',
#   'contact',
#   'report',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetime',
#   'send',
#   'go',
#   'now',
#   'pmsg',
#   'rcvd',
#   'custcare'],
#  ['tadaaaaa', 'home', 'babe', 'still'],
#  ['cool', 'come', 'havent', 'wined', 'dined', 'before'],
#  ['sleepingand', 'surfing'],
#  ['u', 'calling', 'right', 'call', 'hand', 'phone'],
#  ['ok', 'thats', 'great', 'thanx', 'lot'],
#  ['take',
#   'post',
#   'come',
#   'then',
#   'must',
#   'text',
#   'now',
#   'happy',
#   'reading',
#   'one',
#   'wiv',
#   'hello',
#   'caroline',
#   'end',
#   'favourite',
#   'bless'],
#  ['u', 'hiding', 'stranger'],
#  ['not', 'interested', 'like', 'that'],
#  ['sister', 'cleared', 'two', 'round', 'birla', 'soft', 'yesterday'],
#  ['gudnitetcpractice', 'going'],
#  ['dis',
#   'yijue',
#   'jus',
#   'saw',
#   'ur',
#   'mail',
#   'case',
#   'huiming',
#   'havent',
#   'sent',
#   'u',
#   'num',
#   'dis',
#   'num'],
#  ['one', 'small', 'prestige', 'problem', 'now'],
#  ['fancy',
#   'shag',
#   'dointerested',
#   'sextextukcom',
#   'txt',
#   'xxuk',
#   'suzy',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'website',
#   'x'],
#  ['checking', 'you', 'really', 'miss', 'seeing', 'jeremiah', 'great', 'month'],
#  ['nah', 'cant', 'help', 'there', 'ive', 'never', 'iphone'],
#  ['youre', 'not', 'car', 'hour', 'half', 'im', 'going', 'apeshit'],
#  ['today',
#   'sorry',
#   'day',
#   'ever',
#   'angry',
#   'you',
#   'ever',
#   'misbehaved',
#   'hurt',
#   'you',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz',
#   'ur',
#   'fault',
#   'im',
#   'basically',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figure',
#   'much',
#   'need',
#   'alcohol',
#   'jay',
#   'trying',
#   'figure',
#   'much',
#   'safely',
#   'spend',
#   'weed'],
#  ['ltgt', 'ish', 'minute', 'minute', 'ago', 'wtf'],
#  ['thank',
#   'callingforgot',
#   'say',
#   'happy',
#   'onam',
#   'sirjii',
#   'fine',
#   'remembered',
#   'met',
#   'insurance',
#   'personmeet',
#   'qatar',
#   'insha',
#   'allahrakhesh',
#   'ex',
#   'tata',
#   'aig',
#   'joined',
#   'tisscotayseer'],
#  ['ur',
#   'cashbalance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cashin',
#   'send',
#   'cash',
#   'pmsg',
#   'cc',
#   'hgsuitelands',
#   'rowwjhl'],
#  ['im',
#   'actor',
#   'work',
#   'work',
#   'evening',
#   'sleep',
#   'late',
#   'since',
#   'im',
#   'unemployed',
#   'moment',
#   'always',
#   'sleep',
#   'late',
#   'youre',
#   'unemployed',
#   'every',
#   'day',
#   'saturday'],
#  ['hello',
#   'got',
#   'here',
#   'st',
#   'andrewsboy',
#   'long',
#   'way',
#   'cold',
#   'keep',
#   'posted'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikkudb'],
#  ['oh', 'ok', 'no', 'prob'],
#  ['check', 'audreys', 'status', 'right'],
#  ['busy',
#   'here',
#   'trying',
#   'finish',
#   'new',
#   'year',
#   'looking',
#   'forward',
#   'finally',
#   'meeting',
#   'you'],
#  ['good',
#   'afternoon',
#   'sunshine',
#   'dawn',
#   'day',
#   'refreshed',
#   'happy',
#   'alive',
#   'breathe',
#   'air',
#   'smile',
#   'think',
#   'you',
#   'love',
#   'always'],
#  ['well', 'know', 'z', 'take', 'care', 'me', 'no', 'worries'],
#  ['updatenow',
#   'xmas',
#   'offer',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'free',
#   'bluetooth',
#   'double',
#   'min',
#   'txt',
#   'orange',
#   'call',
#   'mobileupd',
#   'calloptoutfq'],
#  ['discount',
#   'code',
#   'rp',
#   'stop',
#   'message',
#   'reply',
#   'stop',
#   'customer',
#   'service'],
#  ['wat', 'uniform', 'get'],
#  ['cool', 'text', 'youre', 'ready'],
#  ['hello',
#   'boytoy',
#   'geeee',
#   'miss',
#   'already',
#   'woke',
#   'up',
#   'wish',
#   'bed',
#   'me',
#   'cuddling',
#   'me',
#   'love'],
#  ['spoil', 'bed', 'well'],
#  ['im', 'going', 'bath', 'msg', 'next', 'ltgt', 'min'],
#  ['cant',
#   'keep',
#   'talking',
#   'people',
#   'not',
#   'sure',
#   'pay',
#   'agree',
#   'price',
#   'pls',
#   'tell',
#   'want',
#   'really',
#   'buy',
#   'much',
#   'willing',
#   'pay'],
#  ['thanks',
#   'ringtone',
#   'order',
#   'reference',
#   't',
#   'charged',
#   'gbp',
#   'per',
#   'week',
#   'unsubscribe',
#   'anytime',
#   'calling',
#   'customer',
#   'service'],
#  ['say', 'happen'],
#  ['could', 'seen', 'mei', 'didt', 'recognise', 'face'],
#  ['well',
#   'there',
#   'not',
#   'lot',
#   'thing',
#   'happening',
#   'lindsay',
#   'new',
#   'year',
#   'sigh',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'something',
#   'going'],
#  ['keep', 'payasam', 'rinu', 'brings'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'called',
#   'me',
#   'sm',
#   'like',
#   'that',
#   'becaus',
#   'he',
#   'verifying',
#   'project',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistake',
#   'me'],
#  ['guess',
#   'thats',
#   'worried',
#   'must',
#   'know',
#   'there',
#   'way',
#   'body',
#   'repair',
#   'itself',
#   'im',
#   'quite',
#   'sure',
#   'shouldnt',
#   'worry',
#   'well',
#   'take',
#   'slow',
#   'first',
#   'tests',
#   'guide',
#   'ovulation',
#   'relax',
#   'nothing',
#   'youve',
#   'said',
#   'reason',
#   'worry',
#   'but',
#   'ill',
#   'keep',
#   'followin',
#   'up'],
#  ['yeah', 'sure', 'give', 'couple', 'minute', 'track', 'wallet'],
#  ['hey', 'leave', 'it', 'not', 'big', 'deal', 'take', 'care'],
#  ['hey', 'late', 'ah', 'meet'],
#  ['double',
#   'min',
#   'txts',
#   'months',
#   'free',
#   'bluetooth',
#   'orange',
#   'available',
#   'sony',
#   'nokia',
#   'motorola',
#   'phones',
#   'call',
#   'mobileupd',
#   'calloptoutndx'],
#  ['took', 'mr', 'owl', 'lick'],
#  ['customer', 'place', 'call', 'you'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['mths',
#   'half',
#   'price',
#   'orange',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   'mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   'update',
#   'now',
#   'orstoptxt'],
#  ['yup', 'lunch', 'buffet', 'now', 'u', 'eat', 'already'],
#  ['huh', 'late', 'fr', 'dinner'],
#  ['hey', 'sat', 'going', 'intro', 'pilate', 'only', 'kickboxing', 'too'],
#  ['morning', 'ok'],
#  ['yes',
#   'think',
#   'so',
#   'office',
#   'but',
#   'lap',
#   'room',
#   'think',
#   'thats',
#   'last',
#   'days',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', 'ish', 'time', 'going'],
#  ['performance',
#   'award',
#   'calculated',
#   'every',
#   'two',
#   'monthnot',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['actually',
#   'sleeping',
#   'still',
#   'might',
#   'u',
#   'call',
#   'back',
#   'text',
#   'gr',
#   'rock',
#   'sis',
#   'send',
#   'u',
#   'text',
#   'wen',
#   'wake'],
#  ['always',
#   'putting',
#   'business',
#   'there',
#   'put',
#   'picture',
#   'as',
#   'facebook',
#   'one',
#   'open',
#   'people',
#   'ive',
#   'ever',
#   'met',
#   'would',
#   'think',
#   'picture',
#   'room',
#   'would',
#   'hurt',
#   'you',
#   'make',
#   'feel',
#   'violated'],
#  ['good',
#   'evening',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkumsharing',
#   'happy',
#   'newsby',
#   'grace',
#   'god',
#   'got',
#   'offer',
#   'tayseertissco',
#   'joinedhope',
#   'fineinshah',
#   'allahmeet',
#   'sometimerakheshvisitor',
#   'india'],
#  ['hmmmkbut',
#   'want',
#   'change',
#   'field',
#   'quickly',
#   'dai',
#   'wan',
#   'na',
#   'get',
#   'system',
#   'administrator',
#   'network',
#   'administrator'],
#  ['free',
#   'ringtone',
#   'text',
#   'first',
#   'poly',
#   'text',
#   'get',
#   'true',
#   'tone',
#   'help',
#   'st',
#   'free',
#   'tone',
#   'xpw',
#   'end',
#   'txt',
#   'stop'],
#  ['dear', 'chechi', 'talk'],
#  ['hair', 'cream', 'not', 'shipped'],
#  ['none', 'thats', 'happening', 'til', 'get', 'though'],
#  ['yep',
#   'great',
#   'loxahatchee',
#   'xmas',
#   'tree',
#   'burning',
#   'ltgt',
#   'start',
#   'hour'],
#  ['haha', 'get', 'used', 'driving', 'usf', 'man', 'know', 'lot', 'stoner'],
#  ['well',
#   'slightly',
#   'disastrous',
#   'class',
#   'pm',
#   'fav',
#   'darlings',
#   'hope',
#   'day',
#   'ok',
#   'coffee',
#   'wld',
#   'good',
#   'cant',
#   'stay',
#   'late',
#   'tomorrow',
#   'time',
#   'place',
#   'always'],
#  ['hello', 'good', 'week', 'fancy', 'drink', 'something', 'later'],
#  ['headin', 'towards', 'busetop'],
#  ['messagesome',
#   'text',
#   'missing',
#   'sendername',
#   'missing',
#   'number',
#   'missing',
#   'sentdate',
#   'missing',
#   'missing',
#   'u',
#   'lot',
#   'thats',
#   'everything',
#   'missing',
#   'sent',
#   'via',
#   'fullonsmscom'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['okies',
#   'ill',
#   'go',
#   'yan',
#   'jiu',
#   'too',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'wendy'],
#  ['dating', 'service', 'call', 'boxskch'],
#  ['whatsup', 'there', 'dont', 'u', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entry',
#   'weekly',
#   'competition',
#   'text',
#   'word',
#   'win',
#   'now',
#   'tc'],
#  ['alright', 'ill', 'head', 'minutes', 'text', 'meet'],
#  ['send',
#   'logo',
#   'ur',
#   'lover',
#   'name',
#   'joined',
#   'heart',
#   'txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'yahoo',
#   'poboxwwq',
#   'txtno',
#   'no',
#   'ad',
#   'p'],
#  ['yesfrom', 'last', 'week', 'im', 'taking', 'live', 'call'],
#  ['someone',
#   'contacted',
#   'dating',
#   'service',
#   'entered',
#   'phone',
#   'fancy',
#   'you',
#   'find',
#   'call',
#   'landline',
#   'poboxntfp'],
#  ['siva', 'hostel', 'aha'],
#  ['urgent',
#   'mobile',
#   'number',
#   'awarded',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs'],
#  ['send',
#   'ur',
#   'friend',
#   'receive',
#   'something',
#   'ur',
#   'voice',
#   'speaking',
#   'expression',
#   'childish',
#   'naughty',
#   'sentiment',
#   'rowdy',
#   'ful',
#   'attitude',
#   'romantic',
#   'shy',
#   'attractive',
#   'funny',
#   'ltgt',
#   'irritating',
#   'ltgt',
#   'lovable',
#   'reply',
#   'me'],
#  ['ok', 'shell', 'ok', 'guess'],
#  ['aathiwhere', 'dear'],
#  ['pain', 'urination', 'thing', 'else'],
#  ['esplanade', 'mind', 'giving', 'lift', 'co', 'got', 'no', 'car', 'today'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgentlyits',
#   'vry',
#   'urgentbut',
#   'hv',
#   'shortage',
#   'ltgt',
#   'lacsthere',
#   'no',
#   'source',
#   'arng',
#   'dis',
#   'amt',
#   'ltgt',
#   'lacsthats',
#   'prob'],
#  ['home', 'watching', 'tv', 'lor'],
#  ['usually',
#   'take',
#   'fifteen',
#   'fucking',
#   'minute',
#   'respond',
#   'yes',
#   'no',
#   'question'],
#  ['congrats',
#   'nokia',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'mins',
#   'vary',
#   'mobile',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wcnxx'],
#  ['booked', 'ticket', 'pongal'],
#  ['available',
#   'now',
#   'im',
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   'amp',
#   'ltgt',
#   'th'],
#  ['message',
#   'sent',
#   'askin',
#   'ltgt',
#   'dollars',
#   'shoul',
#   'pay',
#   'ltgt',
#   'ltgt'],
#  ['ask',
#   'g',
#   'iouri',
#   'ive',
#   'told',
#   'story',
#   'like',
#   'ten',
#   'time',
#   'already'],
#  ['long', 'applebees', 'fucking', 'take'],
#  ['hi',
#   'hope',
#   'u',
#   'get',
#   'txtjourney',
#   'hasnt',
#   'gdnow',
#   'min',
#   'late',
#   'think'],
#  ['but', 'to', 'like', 'love', 'arrange'],
#  ['yeshe',
#   'really',
#   'greatbhaji',
#   'told',
#   'kallis',
#   'best',
#   'cricketer',
#   'sachin',
#   'worldvery',
#   'tough',
#   'get',
#   'out'],
#  ['supposed', 'wake', 'gt'],
#  ['oic', 'saw', 'but', 'tot', 'din', 'c', 'me', 'found', 'group', 'liao'],
#  ['hey',
#   'hey',
#   'werethe',
#   'monkeespeople',
#   'say',
#   'monkeyaround',
#   'howdy',
#   'gorgeous',
#   'howu',
#   'doin',
#   'foundurself',
#   'jobyet',
#   'sausagelove',
#   'jen',
#   'xxx'],
#  ['sorry',
#   'battery',
#   'died',
#   'come',
#   'but',
#   'im',
#   'getting',
#   'gram',
#   'now',
#   'wheres',
#   'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercise',
#   'yeah',
#   'kinda',
#   'remember',
#   'wot',
#   'is',
#   'hmm'],
#  ['wont', 'get', 'concentration', 'dear', 'know', 'mind', 'everything'],
#  ['lol', 'made', 'plan', 'new', 'years'],
#  ['min', 'later', 'k'],
#  ['hank', 'lotsly'],
#  ['thanks', 'hope', 'good', 'day', 'today'],
#  ['kkwhat', 'detail', 'want', 'transferacc', 'no', 'enough'],
#  ['ok',
#   'tell',
#   'stay',
#   'out',
#   'yeah',
#   'tough',
#   'but',
#   'optimistic',
#   'thing',
#   'improve',
#   'month'],
#  ['loan',
#   'purpose',
#   'homeowner',
#   'tenant',
#   'welcome',
#   'previously',
#   'refused',
#   'still',
#   'help',
#   'call',
#   'free',
#   'text',
#   'back',
#   'help'],
#  ['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffles'],
#  ['look',
#   'amy',
#   'ure',
#   'beautiful',
#   'intelligent',
#   'woman',
#   'like',
#   'u',
#   'lot',
#   'know',
#   'u',
#   'dont',
#   'like',
#   'like',
#   'dont',
#   'worry'],
#  ['hope',
#   'thats',
#   'result',
#   'consistently',
#   'intelligent',
#   'kind',
#   'start',
#   'asking',
#   'practicum',
#   'link',
#   'keep',
#   'ear',
#   'open',
#   'best',
#   'ttyl'],
#  ['call',
#   'cost',
#   'guess',
#   'isnt',
#   'bad',
#   'miss',
#   'ya',
#   'need',
#   'ya',
#   'want',
#   'ya',
#   'love',
#   'ya'],
#  ['going',
#   'thru',
#   'different',
#   'feelingwavering',
#   'decision',
#   'coping',
#   'individualtime',
#   'heal',
#   'everything',
#   'believe'],
#  ['u', 'go', 'phone', 'gon', 'na', 'die', 'stay'],
#  ['great', 'never', 'better', 'day', 'give', 'even', 'reason', 'thank', 'god'],
#  ['upgrdcentre',
#   'orange',
#   'customer',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'loyalty',
#   'call',
#   'offer',
#   'end',
#   'th',
#   'july',
#   'tc',
#   'apply',
#   'optout',
#   'available'],
#  ['sorry', 'ill', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'way', 'railway'],
#  ['great',
#   'princess',
#   'love',
#   'giving',
#   'receiving',
#   'oral',
#   'doggy',
#   'style',
#   'fave',
#   'position',
#   'you',
#   'enjoy',
#   'making',
#   'love',
#   'ltgt',
#   'time',
#   'per',
#   'night'],
#  ['dont', 'put', 'stuff', 'road', 'keep', 'getting', 'slippery', 'there'],
#  ['going', 'ride', 'bike'],
#  ['yup', 'no', 'need', 'ill', 'jus', 'wait', 'e', 'rain', 'stop'],
#  ['many', 'company', 'tell', 'language'],
#  ['okmail',
#   'dear',
#   'dave',
#   'final',
#   'notice',
#   'collect',
#   'tenerife',
#   'holiday',
#   'cash',
#   'award',
#   'call',
#   'landline',
#   'tc',
#   'sae',
#   'box',
#   'cwwx',
#   'ppm'],
#  ['long', 'since', 'screamed', 'princess'],
#  ['nothing',
#   'meant',
#   'money',
#   'enters',
#   'account',
#   'here',
#   'bank',
#   'remove',
#   'flat',
#   'rate',
#   'someone',
#   'transfered',
#   'ltgt',
#   'account',
#   'ltgt',
#   'dollar',
#   'got',
#   'removed',
#   'bank',
#   'differ',
#   'charge',
#   'also',
#   'differbe',
#   'sure',
#   'trust',
#   'ja',
#   'person',
#   'sending',
#   'account',
#   'detail',
#   'cos'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'txting',
#   'moan',
#   'nyt',
#   'eca',
#   'pmsgp'],
#  ['nice',
#   'line',
#   'said',
#   'broken',
#   'heart',
#   'plz',
#   'dont',
#   'cum',
#   'time',
#   'infront',
#   'me',
#   'wise',
#   'trust',
#   'u',
#   'good',
#   't'],
#  ['ok', 'im', 'gon', 'na', 'head', 'usf', 'like', 'fifteen', 'minute'],
#  ['love', 'aathilove', 'u', 'lot'],
#  ['tension', 'ahwhat', 'machiany', 'problem'],
#  ['k', 'pick', 'another', 'th', 'youre', 'done'],
#  ['whenre',
#   'guy',
#   'getting',
#   'back',
#   'g',
#   'said',
#   'thinking',
#   'not',
#   'staying',
#   'mcr'],
#  ['almost', 'there', 'see', 'u', 'sec'],
#  ['yo', 'carlos', 'friend', 'already', 'asking', 'you', 'working', 'weekend'],
#  ['watching', 'tv', 'lor'],
#  ['thank', 'baby', 'cant', 'wait', 'taste', 'real', 'thing'],
#  ['change', 'fb', 'jaykwon', 'thuglyfe', 'falconerf'],
#  ['win', 'really', 'no', 'side', 'long', 'time'],
#  ['free',
#   'message',
#   'activate',
#   'free',
#   'text',
#   'message',
#   'replying',
#   'message',
#   'word',
#   'free',
#   'term',
#   'conditions',
#   'visit'],
#  ['dear', 'reached', 'railway', 'happen'],
#  ['depends',
#   'quality',
#   'want',
#   'type',
#   'sent',
#   'boye',
#   'faded',
#   'glory',
#   'want',
#   'ralphs',
# ...
#   'came',
#   'home'],
#  ['spoon', 'okay'],
#  ['say', 'somebody', 'named', 'tampa'],
#  ['work', 'now', 'going', 'min'],
#  ['brother', 'genius'],
#  ['sorry',
#   'guess',
#   'whenever',
#   'get',
#   'hold',
#   'connections',
#   'maybe',
#   'hour',
#   'two',
#   'ill',
#   'text'],
#  ['u', 'find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff', 'out'],
#  ['dude', 'ive', 'seeing', 'lotta', 'corvette', 'lately'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'either',
#   'yr',
#   'supply',
#   'cd',
#   'virgin',
#   'record',
#   'mystery',
#   'gift',
#   'guaranteed',
#   'call',
#   'tscs',
#   'pm',
#   'approx',
#   'mins'],
#  ['here',
#   'but',
#   'consider',
#   'wall',
#   'bunker',
#   'shit',
#   'important',
#   'never',
#   'play',
#   'peaceful',
#   'but',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'dont',
#   'matter'],
#  ['private',
#   'account',
#   'statement',
#   'xxxxxx',
#   'show',
#   'unredeemed',
#   's',
#   'i',
#   'm',
#   'points',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['hello',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champneys',
#   'put',
#   'down',
#   'need',
#   'address',
#   'dob',
#   'asap',
#   'ta',
#   'r'],
#  ['u',
#   'want',
#   'xmas',
#   'free',
#   'text',
#   'message',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'call',
#   'free',
#   'find',
#   'more'],
#  ['well',
#   'officially',
#   'philosophical',
#   'hole',
#   'u',
#   'wan',
#   'na',
#   'call',
#   'home',
#   'ready',
#   'saved'],
#  ['going',
#   'goodno',
#   'problembut',
#   'still',
#   'need',
#   'little',
#   'experience',
#   'understand',
#   'american',
#   'customer',
#   'voice'],
#  ['ill', 'text', 'drop', 'x'],
#  ['ugh', 'long', 'day', 'im', 'exhausted', 'want', 'cuddle', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day',
#   'otherwise',
#   'miss',
#   'best',
#   'friend',
#   'world',
#   'shakespeare',
#   'shesil',
#   'ltgt'],
#  ['shop',
#   'till',
#   'u',
#   'drop',
#   'you',
#   'either',
#   'k',
#   'k',
#   'cash',
#   'travel',
#   'voucher',
#   'call',
#   'now',
#   'ntt',
#   'po',
#   'box',
#   'crbt',
#   'fixedline',
#   'cost',
#   'ppm',
#   'mobile',
#   'vary'],
#  ['castor', 'need', 'see', 'something'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'q',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'u',
#   'know',
#   'country',
#   'liverpool',
#   'played',
#   'mid',
#   'week',
#   'txt',
#   'ansr',
#   'sptyrone'],
#  ['u',
#   'secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcall'],
#  ['u',
#   'secret',
#   'admirer',
#   'looking',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcall',
#   'stopsms'],
#  ['reminder',
#   'not',
#   'downloaded',
#   'content',
#   'already',
#   'paid',
#   'for',
#   'goto',
#   'mymoby',
#   'tv',
#   'collect',
#   'content'],
#  ['see',
#   'knew',
#   'giving',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'always',
#   'wanting',
#   'miss',
#   'curfew',
#   'gon',
#   'na',
#   'gibe',
#   'til',
#   'one',
#   'but',
#   'midnight',
#   'movie',
#   'not',
#   'gon',
#   'na',
#   'get',
#   'til',
#   'need',
#   'come',
#   'home',
#   'need',
#   'getsleep',
#   'and',
#   'anything',
#   'need',
#   'b',
#   'studdying',
#   'ear',
#   'training'],
#  ['love', 'give', 'massages', 'use', 'lot', 'baby', 'oil', 'fave', 'position'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'u',
#   'know',
#   'change',
#   'permission',
#   'drive',
#   'mac',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsoldmike', 'hussey'],
#  ['like', 'talk', 'pa', 'but', 'not', 'able', 'to', 'dont', 'know', 'y'],
#  ['dun',
#   'cut',
#   'short',
#   'leh',
#   'u',
#   'dun',
#   'like',
#   'ah',
#   'failed',
#   'shes',
#   'quite',
#   'sad'],
#  ['unbelievable', 'faglord'],
#  ['wifehow', 'knew', 'time', 'murder', 'exactly'],
#  ['ask', 'princess'],
#  ['great', 'princess', 'thinking', 'me'],
#  ['nutter', 'cutter', 'ctter', 'cttergg', 'cttargg', 'ctargg', 'ctagg', 'ie'],
#  ['ok',
#   'noe',
#   'ure',
#   'busy',
#   'but',
#   'im',
#   'really',
#   'bored',
#   'msg',
#   'u',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choose',
#   'one'],
#  ['doesnt',
#   'g',
#   'class',
#   'early',
#   'tomorrow',
#   'thus',
#   'shouldnt',
#   'trying',
#   'smoke',
#   'ltgt'],
#  ['superb',
#   'thought',
#   'grateful',
#   'u',
#   'dont',
#   'everything',
#   'u',
#   'want',
#   'mean',
#   'u',
#   'still',
#   'opportunity',
#   'happier',
#   'tomorrow',
#   'u',
#   'today'],
#  ['hope', 'good', 'week', 'checking'],
#  ['im',
#   'used',
#   'it',
#   'hope',
#   'agent',
#   'dont',
#   'drop',
#   'since',
#   'ive',
#   'booked',
#   'thing',
#   'year',
#   'whole',
#   'boston',
#   'nyc',
#   'experiment'],
#  ['thursday', 'night', 'yeah', 'sure', 'thing', 'well', 'work'],
#  ['probably',
#   'money',
#   'worries',
#   'thing',
#   'coming',
#   'due',
#   'several',
#   'outstanding',
#   'invoice',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago'],
#  ['possible', 'teach', 'you', 'where'],
#  ['wonder', 'phone', 'battery', 'went', 'dead', 'tell', 'you', 'love', 'babe'],
#  ['lovely', 'smell', 'bus', 'aint', 'tobacco'],
#  ['getting',
#   'worried',
#   'here',
#   'derek',
#   'taylor',
#   'already',
#   'assumed',
#   'worst'],
#  ['hey', 'whats', 'charles', 'sorry', 'late', 'reply'],
#  ['lastest',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'strokes',
#   'win',
#   'nookii',
#   'game',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap'],
#  ['ill',
#   'give',
#   'it',
#   'plus',
#   'said',
#   'grinule',
#   'greet',
#   'whenever',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'pmin',
#   'cheap',
#   'pmin',
#   'peak',
#   'stop',
#   'text',
#   'call',
#   'pmin'],
#  ['love',
#   'come',
#   'took',
#   'long',
#   'leave',
#   'zahers',
#   'got',
#   'word',
#   'ym',
#   'happy',
#   'see',
#   'but',
#   'sad',
#   'left',
#   'miss'],
#  ['sorry', 'hurt', 'you'],
#  ['cant',
#   'feel',
#   'nauseous',
#   'im',
#   'pissed',
#   'didnt',
#   'eat',
#   'sweet',
#   'week',
#   'cause',
#   'today',
#   'planning',
#   'pig',
#   'out',
#   'dieting',
#   'week',
#   'im',
#   'not',
#   'hungry'],
#  ['ok', 'lor', 'but', 'not', 'early', 'still', 'project', 'meeting', 'now'],
#  ['call', 'da', 'waiting', 'call'],
#  ['could', 'ask', 'carlos', 'could', 'get', 'anybody', 'else', 'chip'],
#  ['actually', 'send', 'reminder', 'today', 'wonderful', 'weekend'],
#  ['people',
#   'see',
#   'msgs',
#   'think',
#   'iam',
#   'addicted',
#   'msging',
#   'wrong',
#   'bcoz',
#   'dont',
#   'know',
#   'iam',
#   'addicted',
#   'sweet',
#   'friends',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'registered',
#   'driving',
#   'ah',
#   'tmr',
#   'wan',
#   'na',
#   'meet',
#   'yck'],
#  ['dont', 'talk', 'ever', 'ok', 'word'],
#  ['u', 'wana', 'see'],
#  ['way', 'school', 'pls', 'send', 'ashleys', 'number'],
#  ['shall', 'fine', 'avalarr', 'now', 'hollalater'],
#  ['went',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'todaybut',
#   'still',
#   'didt',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'old',
#   'websitenow',
#   'blogging',
#   'magicalsongsblogspotcom'],
#  ['k', 'wait', 'chikkuil', 'send', 'aftr', 'ltgt', 'min'],
#  ['but',
#   'im',
#   'diet',
#   'ate',
#   'many',
#   'slice',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'im',
#   'always',
#   'diet'],
#  ['ki', 'give', 'kvb', 'acc', 'detail'],
#  ['oh', 'come', 'ah'],
#  ['money',
#   'r',
#   'lucky',
#   'winner',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   'million',
#   'give',
#   'away',
#   'pptxnormal',
#   'text',
#   'rate',
#   'box',
#   'wtjy'],
#  ['im',
#   'really',
#   'sorry',
#   'wont',
#   'b',
#   'able',
#   'fridayhope',
#   'u',
#   'find',
#   'alternativehope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   'wa',
#   'enjoy',
#   'wish',
#   'many',
#   'happy',
#   'moment',
#   'fro',
#   'wherever',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'youll', 'it', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'landline',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'tc',
#   'box',
#   'skxh'],
#  ['dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'side', 'fever', 'vomitin'],
#  ['kkare', 'college'],
#  ['urgent',
#   'call',
#   'landline',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'tc',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'friday',
#   'stuffed',
#   'like',
#   'pig',
#   'yesterday',
#   'feel',
#   'bleh',
#   'but',
#   'least',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'bleh'],
#  ['no',
#   'sell',
#   'well',
#   'ton',
#   'coins',
#   'sell',
#   'coin',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'life',
#   'pocket'],
#  ['theyre', 'lot', 'places', 'hospital', 'medical', 'place', 'safe'],
#  ['getting',
#   'touch',
#   'folk',
#   'waiting',
#   'company',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'in',
#   'enjoy',
#   'community',
#   'psms'],
#  ['also',
#   'ive',
#   'sorta',
#   'blown',
#   'couple',
#   'time',
#   'recently',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'blue',
#   'looking',
#   'weed'],
#  ['sent',
#   'score',
#   'sophas',
#   'secondary',
#   'application',
#   'schools',
#   'think',
#   'thinking',
#   'applying',
#   'research',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'school',
#   'one',
#   'le',
#   'expensive',
#   'one'],
#  ['cant', 'wait', 'see', 'you', 'photo', 'useful'],
#  ['ur',
#   'cashbalance',
#   'currently',
#   'pound',
#   'maximize',
#   'ur',
#   'cashin',
#   'send',
#   'go',
#   'pmsg',
#   'cc',
#   'po',
#   'box',
#   'tcrw'],
#  ['hey',
#   'booked',
#   'kb',
#   'sat',
#   'already',
#   'lesson',
#   'going',
#   'ah',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodging'],
#  ['chk', 'ur', 'belovd', 'm', 'dict'],
#  ['time', 'want', 'come'],
#  ['awesome', 'lem', 'me', 'know', 'whenever', 'youre', 'around'],
#  ['shb', 'b', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'gravity',
#   'read',
#   'carefully',
#   'heart',
#   'feel',
#   'light',
#   'someone',
#   'it',
#   'but',
#   'feel',
#   'heavy',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'get', 'dobbys', 'bowl', 'car'],
#  ['filthy', 'story', 'girl', 'waiting'],
#  ['sorry',
#   'c',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'poor',
#   'thing',
#   'but',
#   'one',
#   'night',
#   'tmr',
#   'ull',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isnt',
#   'decision',
#   'feeling',
#   'could',
#   'decide',
#   'love',
#   'then',
#   'life',
#   'would',
#   'much',
#   'simpler',
#   'but',
#   'le',
#   'magical'],
#  ['welp', 'apparently', 'retired'],
#  ['sort',
#   'code',
#   'acc',
#   'no',
#   'bank',
#   'natwest',
#   'reply',
#   'confirm',
#   'ive',
#   'sent',
#   'right',
#   'person'],
#  [],
#  ['u', 'sure', 'u', 'cant', 'take', 'sick', 'time'],
#  ['urgent',
#   'trying',
#   'contact',
#   'u',
#   'today',
#   'draw',
#   'show',
#   'prize',
#   'guaranteed',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'm',
#   'validhrs'],
#  ['yo',
#   'chad',
#   'gymnastics',
#   'class',
#   'wan',
#   'na',
#   'take',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', 'ltgt', 'me'],
#  ['not', 'sure', 'night', 'menu', 'know', 'noon', 'menu'],
#  ['u',
#   'want',
#   'come',
#   'backa',
#   'beautiful',
#   'necklace',
#   'token',
#   'heart',
#   'youthats',
#   'give',
#   'but',
#   'wife',
#   'likingbe',
#   'seeno',
#   'one',
#   'give',
#   'thatdont',
#   'call',
#   'mei',
#   'wait',
#   'till',
#   'come'],
#  ['willing', 'go', 'aptitude', 'class'],
#  ['wont', 'b', 'trying', 'sort', 'house', 'out', 'ok'],
#  ['yar',
#   'lor',
#   'wan',
#   'go',
#   'c',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice',
#   'u'],
#  ['haha', 'awesome', 'omw', 'back'],
#  ['yup', 'thk', 'e', 'shop', 'close', 'lor'],
#  ['account', 'number'],
#  ['eh', 'u', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'u',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'u',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesitate',
#   'know',
#   'second',
#   'time',
#   'weakness',
#   'like',
#   'that',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anything',
#   'changed',
#   'day',
#   'sure',
#   'nothing'],
#  ['hey', 'pay', 'salary', 'de', 'ltgt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'alcohol'],
#  ['started',
#   'searching',
#   'get',
#   'job',
#   'dayshe',
#   'great',
#   'potential',
#   'talent'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', 'carpark'],
#  ['congrats',
#   'mobile',
#   'g',
#   'videophones',
#   'r',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'mates',
#   'play',
#   'java',
#   'games',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look', 'fuckin', 'time', 'fuck', 'think'],
#  ['yo', 'guess', 'dropped'],
#  ['carlos', 'say', 'hell', 'mu', 'ltgt', 'minute'],
#  ['im', 'office', 'call', 'ltgt', 'min'],
#  ['geeee',
#   'miss',
#   'already',
#   'know',
#   'think',
#   'about',
#   'fuck',
#   'cant',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ahthe',
#   'ubi',
#   'one',
#   'say',
#   'wan',
#   'call',
#   'tomorrowcall',
#   'look',
#   'ireneere',
#   'got',
#   'bus',
#   'ubi',
#   'cresubi',
#   'tech',
#   'parkph',
#   'st',
#   'wkg',
#   'daysn'],
#  ['ugh', 'got', 'ta', 'drive', 'back', 'sd', 'la', 'butt', 'sore'],
#  ['th', 'july'],
#  ['hi',
#   'im',
#   'relaxing',
#   'time',
#   'ever',
#   'get',
#   'am',
#   'every',
#   'day',
#   'party',
#   'good',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'ish'],
#  ['wan', 'come', 'come', 'lor', 'but', 'din', 'c', 'stripe', 'skirt'],
#  ['xmas',
#   'story',
#   'peace',
#   'xmas',
#   'msg',
#   'love',
#   'xmas',
#   'miracle',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'u',
#   'merry',
#   'xmas'],
#  ['cant', 'dont', 'number'],
#  ['change', 'again', 'e', 'one', 'next', 'escalator'],
#  ['yetunde', 'im', 'class', 'not', 'run', 'water', 'make', 'ok', 'pls', 'now'],
#  ['not',
#   'lot',
#   'happened',
#   'here',
#   'feel',
#   'quiet',
#   'beth',
#   'aunt',
#   'charlie',
#   'working',
#   'lots',
#   'helen',
#   'mo',
#   'been'],
#  ['wait',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'dun',
#   'c',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'n',
#   'pick'],
#  ['aight', 'do', 'thanks', 'comin'],
#  ['nobut', 'heard', 'abt', 'tat'],
#  ['ltgt', 'think', 'say', 'syllabus'],
#  ['umma', 'say', 'anything'],
#  ['give', 'sec', 'think', 'think'],
#  ['panasonic',
#   'bluetoothhdset',
#   'free',
#   'nokia',
#   'free',
#   'motorola',
#   'free',
#   'doublemins',
#   'doubletxt',
#   'orange',
#   'contract',
#   'call',
#   'mobileupd',
#   'call',
#   'optout'],
#  ['dont',
#   'quite',
#   'know',
#   'do',
#   'still',
#   'cant',
#   'get',
#   'hold',
#   'anyone',
#   'cud',
#   'pick',
#   'bout',
#   'pm',
#   'see',
#   'theyre',
#   'pub'],
#  ['poyyarikaturkolathupalayamunjalur', 'posterode', 'dis', 'ltgt'],
#  ['dear',
#   'heroi',
#   'leaving',
#   'qatar',
#   'tonite',
#   'apt',
#   'opportunitypls',
#   'keep',
#   'touch',
#   'ltemailgt',
#   'kerala'],
#  ['lol',
#   'would',
#   'but',
#   'mom',
#   'would',
#   'fit',
#   'tell',
#   'whole',
#   'family',
#   'crazy',
#   'terrible'],
#  ['got', 'home', 'babe', 'still', 'awake'],
#  ['dunno', 'close', 'oredi', 'not', 'v', 'fan'],
#  ['buy', 'pizza', 'meat', 'lover', 'supreme', 'u', 'get', 'pick'],
#  ['ya', 'toldshe', 'asking', 'wats', 'matter'],
#  ['dearregret',
#   'cudnt',
#   'pick',
#   'calldrove',
#   'frm',
#   'ctla',
#   'cochin',
#   'homeleft',
#   'mobile',
#   'carente',
#   'style',
#   'ishtamayoohappy',
#   'bakrid'],
#  ['free',
#   'st',
#   'week',
#   'no',
#   'nokia',
#   'tone',
#   'ur',
#   'mob',
#   'every',
#   'week',
#   'txt',
#   'nokia',
#   'get',
#   'txting',
#   'tell',
#   'ur',
#   'mate',
#   'pobox',
#   'wwq',
#   'normptone'],
#  ['shall', 'send', 'exe', 'mail', 'id'],
#  ['nope', 'watching', 'tv', 'home', 'not', 'going', 'out', 'v', 'bored'],
#  ['knowwait', 'check', 'it'],
#  ['good',
#   'afternoon',
#   'glorious',
#   'anniversary',
#   'day',
#   'sweet',
#   'j',
#   'hope',
#   'find',
#   'happy',
#   'content',
#   'prey',
#   'think',
#   'send',
#   'teasing',
#   'kiss',
#   'across',
#   'sea',
#   'coaxing',
#   'image',
#   'fond',
#   'souveniers',
#   'cougarpen'],
#  ['guess',
#   'what',
#   'somebody',
#   'know',
#   'secretly',
#   'fancy',
#   'you',
#   'wan',
#   'na',
#   'find',
#   'is',
#   'give',
#   'u',
#   'call',
#   'landline',
#   'dateboxessexcmxn',
#   'pmin'],
#  ['still', 'tonight'],
#  ['may', 'call', 'later', 'pls'],
#  ['hasnt', 'pattern', 'recently', 'crap', 'weekends'],
#  ['sore', 'throat', 'scratch', 'talk'],
#  ...]

# %%
# Initialize and train the Word2Vec model
model = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)  # vector_size is the length of the word vectors

# %%
#Convert text data to Word2Vec embeddings
def get_sentence_embedding(tokens, model):
    """
    Get the average Word2Vec vector for a sentence (list of tokens).
    If a token is not in the model's vocabulary, it is ignored.
    """
    # Get vectors for words in the model's vocabulary
    valid_words = [model.wv[word] for word in tokens if word in model.wv]
    
    if not valid_words:
        # If no valid words, return a zero vector
        return [0] * model.vector_size
    
    # Calculate the average vector for the sentence
    return list(sum(valid_words) / len(valid_words))

# %%
# Apply the function to get Word2Vec embeddings for each row
df['word2vec_embedded_vector'] = df['tokenized_text'].apply(lambda tokens: get_sentence_embedding(tokens, model))

# %%
df.sample(4)
# Out:
#       label                                               text  word_count  \
# 11287   ham  begin pgp signed message hash shanumber conten...         232
# 1177    ham           yo game almost over want go walmart soon          11
# 13665  spam  traveled chicago husband romantic weekend away...          67
# 4330    ham                    hide anythiing keeping distance           9
#
#        num_stop_words  num_chars  num_punctuation_chars  \
# 11287              62       1519                      0
# 1177                3         52                      2
# 13665              27        392                     10
# 4330                5         49                      0
#
#        word_count_after_preprocessing  num_chars_after_preprocessing  \
# 11287                             169                           1219
# 1177                                8                             40
# 13665                              41                            281
# 4330                                4                             31
#
#                                           tokenized_text  \
# 11287  [begin, pgp, signed, message, hash, shanumber,...
# 1177   [yo, game, almost, over, want, go, walmart, soon]
# 13665  [traveled, chicago, husband, romantic, weekend...
# 4330                [hide, anythiing, keeping, distance]
#
#                                 word2vec_embedded_vector
# 11287  [-0.52670753, 0.043331273, -1.0631641, 0.13854...
# 1177   [-0.12471256, -0.11388658, -1.1051327, -0.3513...
# 13665  [-0.21170694, 0.01254996, -1.3142825, -0.61478...
# 4330   [-0.16022897, 0.06158752, -0.4214239, -0.21287...

# %%
df1=df[['label','word_count','num_stop_words','num_chars','num_punctuation_chars','word_count_after_preprocessing','num_chars_after_preprocessing','word2vec_embedded_vector']]

# %%
df1
# Out:
#       label  word_count  num_stop_words  num_chars  num_punctuation_chars  \
# 0       ham          20               4        111                      9
# 1       ham           6               0         29                      6
# 2      spam          28               5        155                      5
# 3       ham          11               2         49                      6
# 4       ham          13               6         61                      2
# ...     ...         ...             ...        ...                    ...
# 14612   ham         131              59        745                     24
# 14613   ham         121              62        670                     18
# 14614   ham         141              72        770                      9
# 14615   ham          86              47        448                     16
# 14616   ham         260             139       1363                     35
#
#        word_count_after_preprocessing  num_chars_after_preprocessing  \
# 0                                  16                             82
# 1                                   6                             23
# 2                                  20                            110
# 3                                   9                             35
# 4                                   8                             40
# ...                               ...                            ...
# 14612                              74                            517
# 14613                              63                            430
# 14614                              69                            490
# 14615                              41                            266
# 14616                             126                            845
#
#                                 word2vec_embedded_vector
# 0      [-0.44536713, -0.101509035, -1.050856, -0.2630...
# 1      [-0.33632967, -0.17212276, -0.87967306, -0.000...
# 2      [-0.23400958, -0.0057888003, -0.75428146, 0.01...
# 3      [-0.3609581, -0.032422144, -1.5170497, -0.1118...
# 4      [-0.10801181, -0.021496635, -1.3440485, -0.605...
# ...                                                  ...
# 14612  [-0.25193012, -0.063167185, -1.1948055, -0.387...
# 14613  [-0.1882756, -0.060200736, -1.2349558, -0.3945...
# 14614  [-0.237662, -0.07663142, -1.2476673, -0.374296...
# 14615  [-0.34076858, -0.05880893, -1.1384875, -0.3845...
# 14616  [-0.29835936, -0.08576413, -1.2402604, -0.3960...
#
# [14617 rows x 8 columns]

# %%
df1.to_csv('word2vec_embedded.csv',index=False)
